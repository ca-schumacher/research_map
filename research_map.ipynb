# %% [markdown]
# # Data visualization of my research activites around the world

# %% [markdown]
# Import libraries:

# %%
# %matplotlib inline
import folium
from folium import plugins
from folium.plugins import MarkerCluster
import branca
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Make/ Import Data to show on the map

# %%
data = pd.DataFrame({
#      
'lat':[13.393648, -71.091907, 12.399829, 8.656081,  8.656081,  8.716400,  18.428955,  18.428955,  141.340260, 9.937403,  139.778022, -87.209535, 6.849999,  6.849999,  6.564451,  -21.800316, 135.524285, 4.371367,  9.080576,  8.661714,  8.656081,  4.371367],
'lon':[52.518841, 42.358561,  51.397994, 49.874848, 49.874848, 49.413535, -33.917294, -33.917294, 43.078012,  51.541028, 35.618565,  30.413238,  52.239817, 52.239817, 46.519978, 64.123514,  34.822146,  52.000844, 48.747028, 50.095338, 49.874848, 52.000844],
})

items = 2
con_DVS2015 = """ <h6> Poster Presentation </h6> <h4> Annual Congress of the German Biomechanics Section </h4> <h5> 'Model-based Investigation of Neuromuscular Adaptation Mechanisms with different Leg Elasticity' </h5> <h5> Humboldt-Universität Berlin <br> 26-28 Mar 2015 </h5>"""
con_AMAM2015 = """ <h6> Poster Presentation </h6> <h4> 7th Int. Symposium on Adaptive Motions of Animals and Machine </h4> <h5> 'Optimal Leg Muscle Function for Running and Jumping Tasks' </h5> <h5> Massachusetts Institute of Technology (MIT) <br> 21-25 Jun 2015 </h5>"""
con_DGR2016  = """ <h6> Poster Presentation </h6> <h4> DGR-Days </h4> <h5> 'System Identification of a Feed-forward controlled Robotic Leg to mimic Human Running Gaits' </h5> <h5> RoboCup 2016 <br> 29-30 Jun 2016 </h5>"""
con_DVS2016  = """ <h6> Poster Presentation </h6> <h4> 11th joint Conference on Motor Control & Learning, Biomechanics & Training </h4> <h5> 'Neuromuscular model mimics walking gaits of a unilateral trans-tibial amputee' </h5> <h5> Technische Universität Darmstadt  <br> 20-30 Sep 2016 </h5>"""
con_DVS20162  = """ <h6> Poster Presentation </h6> <h4> 11th joint Conference on Motor Control & Learning, Biomechanics & Training </h4> <h5> 'Evaluation of Sensor Functionality for Acquiring the Relative Movement between Residual Limb and Prosthetic Socket' </h5> <h5> Technische Universität Darmstadt  <br> 20-30 Sep 2016 </h5>"""
con_Neuro2016  = """ <h6> Poster Presentation </h6> <h4> International Symposium on the Neuromechanics of Human Movement </h4> <h5> 'Gait pattern adaptations of a neuromuscular model describing walking of a unilateral transtibial amputee' </h5> <h5> University Heidelberg <br> 4-6 Oct 2016 </h5>"""
con_ISPO2017  = """ <h6> Poster Presentation </h6> <h4> ISPO World Congress </h4> <h5> 'Sensitivity Analysis of Socket Interaction Forces in Unilateral Transtibial Amputee Walking: A Neuromuscular Simulation Study' </h5> <h5> Cape Town International Convention Center <br> 8-11 May 2017 </h5>"""
con_ISPO20172  = """ <h6> Poster Presentation </h6> <h4> ISPO World Congress </h4> <h5> 'Feasibility Study Using an Orthosis: An Approach to Measuring the Relative Movement between Residual Limb and Prosthetic Socket in Dynamic Gait Situations' </h5> <h5> Cape Town International Convention Center <br> 8-11 May 2017 </h5>"""
con_AMAM2017 = """ <h6> Poster Presentation </h6> <h4> 8th Int. Symposium on Adaptive Motions of Animals and Machine </h4> <h5> 'Feedback pathway compositions for hopping - influence of changes in body morphology and ground compliance' </h5> <h5> Hokkaido University <br> 27-30 Jun 2017 </h5>"""
con_Bernstein2017 = """ <h6> Poster Presentation </h6> <h4> Bernstein Conference 2017 </h4> <h5> 'Sensor-motor maps for hopping – influence of changes in muscle properties' </h5> <h5> Georg-August-Universität Göttingen <br> 13-15 Sep 2017 </h5>"""
con_AIST2018 = """ <h6> Poster Presentation </h6> <h4> International Research Forum on Biomechanics of Running-specific Prostheses (IBRSP2018) </h4> <h5> 'Dynamics of amputee long jump' </h5> <h5> AIST Tokyo <br> 21 Feb 2018 </h5>"""
con_DW2018 = """ <h6> Talk and Poster Presentation </h6> <h4> 13th Annual Dynamic Walking Conference </h4> <h5> 'Sensor-Motor Maps of a perturbed bipedal hopping model' </h5> <h5> Institute for Human and Machine Cognition (ihmc) <br> 21-24 May 2018 </h5>"""
con_BioRob2018 = """ <h6> Paper Presentation </h6> <h4> 7th IEEE RAS/EMBS International Conference on Biomedical Robotics and Biomechatronics </h4> <h5> 'Force-Feedback Coordinates Stance and Balance Locomotor Subfunctions in Hopping' </h5> <h5> University of Twente <br> 26-29 Aug 2018 </h5>"""
con_BioRob20182 = """ <h6> Paper Presentation </h6> <h4> 7th IEEE RAS/EMBS International Conference on Biomedical Robotics and Biomechatronics </h4> <h5> 'A Movement Manipulator to Introduce Temporary and Local Perturbations in Human Hopping' </h5> <h5> University of Twente <br> 26-29 Aug 2018 </h5>"""
con_AMAM2019 = """ <h6> Poster Presentation </h6> <h4> 9th Int. Symposium on Adaptive Motions of Animals and Machine </h4> <h5> 'Role of trunk inertia in non-stepping balance recovery' </h5> <h5> École Polytechnique Fédérale de Lausanne (EPFL) <br> 20-23 Aug 2019 </h5>"""
talk_Ossur = """ <h6> Invited Talk </h6> <h4> Ossur hf </h4> <h5> 'Robotic Bipedal Walking Emulator as a novel Design Methodology for Hardware-in-the-loop Testing' </h5> <h5> Ossur Headquaters <br> 1 Dec 2015 </h5>"""
talk_Osaka = """ <h6> Invited Talk </h6> <h4> Adaptive Robotics Lab </h4> <h5> 'Functional Reflex Composition in Hopping' </h5> <h5> Osaka University <br> 3 Jul 2017 </h5>"""
talk_Delft = """ <h6> Invited Talk </h6> <h4> Biorobotics Lab </h4> <h5> 'Sensor-motor Maps in Hopping' </h5> <h5> Delft University of Technology <br> 20 Oct 2017 </h5>"""
talk_Planck = """ <h6> Invited Talk </h6> <h4> Dynamic Locomotion Group </h4> <h5> 'Embodiment in Hopping and Balance: Principles of Sensory Integration and Human Leg Design' </h5> <h5> Max Planck Institute for Intelligent Systems <br> 22 Feb 2018 </h5>"""
talk_FFM = """ <h6> Invited Talk </h6> <h4> Cognitive Neuroscience Group </h4> <h5> 'The role of blending sensory pathways for generating goal directed movements' </h5> <h5> University Hospital Frankfurt <br> 5 May 2019 </h5>"""
PhD = """ <h4> Technische Universität Darmstadt </h4> <h6> Locomotion Laboratory, <br> Insitute for Sport Science </h6> <h5> PhD <br> 2014-2019 </h5>"""
Guest = """ <h4> Delft University of Technology </h4> <h6> Biorobotics Lab <br> Mechanical, Maritime and Materials Engineering </h6> <h5> Guest Researcher <br> Apr-Sep 2018 </h5>"""

html = [con_DVS2015, con_AMAM2015, con_DGR2016, con_DVS2016, con_DVS20162, con_Neuro2016, con_ISPO2017, con_ISPO20172, con_AMAM2017, con_Bernstein2017, con_AIST2018, con_DW2018, con_BioRob2018, con_BioRob20182, con_AMAM2019, talk_Ossur, talk_Osaka, talk_Delft, talk_Planck, talk_FFM, PhD, Guest]
# PhD = 'gray', poster = 'green', paper / talk = 'darkblue', invited talk = 'darkred',
colors = ['green','green','green','green','green','green','green','green','green','green','green', 'green', 'darkblue', 'darkblue', 'darkblue', 'darkred', 'darkred', 'darkred', 'darkred', 'darkred','gray','gray']

# %%
coord_Osa = pd.read_csv('DA_Osaka.csv', delimiter=r"\s+", usecols=[1,2])
coords_Osa = list(zip(coord_Osa['latitude'], coord_Osa['longitude']))
coord_Cape = pd.read_csv('DA_Cape.csv', delimiter=r"\s+", usecols=[1,2])
coords_Cape = list(zip(coord_Cape['latitude'], coord_Cape['longitude']))
coord_MIT = pd.read_csv('DA_MIT.csv', delimiter=r"\s+", usecols=[1,2])
coords_MIT = list(zip(coord_MIT['latitude'], coord_MIT['longitude']))
coord_Ossur = pd.read_csv('DA_Ossur.csv', delimiter=r"\s+", usecols=[1,2])
coords_Ossur = list(zip(coord_Ossur['latitude'], coord_Ossur['longitude']))
coord_AMAM = pd.read_csv('DA_Sapporo.csv', delimiter=r"\s+", usecols=[1,2])
coords_AMAM = list(zip(coord_AMAM['latitude'], coord_AMAM['longitude']))
coord_DW = pd.read_csv('Delft_Pensa.csv', delimiter=r"\s+", usecols=[1,2])
coords_DW = list(zip(coord_DW['latitude'], coord_DW['longitude']))

# %% [markdown]
# Create the raw map

# %%
f = folium.Figure(width=1000, height=500)
m = folium.Map(location=[50, 10], world_copy_jump=True, zoom_start=5, min_zoom = 1.7, tiles="openstreetmap").add_to(f)

marker_cluster = MarkerCluster(
    name='research_map',
    overlay=True,
    control=False
)

for i in range(0,len(html)):
    loca = data.iloc[i]['lon'], data.iloc[i]['lat']
    marker = folium.Marker(location=loca)
    iframe = branca.element.IFrame(html=html[i], width=500, height=200)
    popup = html[i]
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

# %% [markdown]
# alternative version with different marker colors:

# %%
#m = folium.Map(location=[53, 10], zoom_start=1.5)
#for i in range(0,len(html)):
#    iframe = branca.element.IFrame(html=html[i], width=1000, height=500)
#    popup = folium.Popup(iframe)
#    folium.Marker([data.iloc[i]['lon'], data.iloc[i]['lat']], popup=html[i], icon=folium.Icon(color=colors[i])).add_to(m)
#    #m.drawgreatcircle(startlon,startlat,arrlon,arrlat, linewidth=2, color='orange')

# %%
folium.PolyLine(coords_Osa, color="grey", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(coords_Cape, color="grey", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(coords_MIT, color="grey", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(coords_AMAM, color="grey", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(coords_DW, color="grey", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(coords_Ossur, color="grey", weight=2.5, opacity=1).add_to(m)

# %%
m
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="1000" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
plugins.Fullscreen(
    position='topright',
    title='Expand me',
    title_cancel='Exit me',
    force_separate_button=True
).add_to(m)

plugins.ScrollZoomToggler().add_to(m)

#minimap = plugins.MiniMap()
#m.add_child(minimap)
m.save('research_map.html')
